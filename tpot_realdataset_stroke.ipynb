# %% [markdown]
# <h1>Aprendizaje automático automatizado usando TPOT para predecir accidentes cerebrovasculares</h1>

# %% [markdown]
# <hr>

# %% [markdown]
# <h3>En este Notebook se va a preparar y ejecutar aprendizaje automático automatizado sobre el <i>dataset</i> 'healthcare-dataset-stroke-data.csv' (https://www.kaggle.com/fedesoriano/stroke-prediction-dataset) para conseguir un modelo capaz de predecir si un paciente con determinadas características médicas sufrirá una isquemia cerebral o si por el contrario no es propenso a ello</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>1. Importación de librerías y preparación del <i>dataset</i></h2>

# %% [markdown]
# <p>En primer lugar, se importan los paquetes y librerías necesarias para la ejecución del código:</p>

# %%
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %% [markdown]
# <p>A continuación, se procede a la lectura de los datos del archivo <i>healthcare-dataset-stroke-data.csv</i>. Para ello, se han visualizado los datos en bruto previamente para conocer qué atributos hay y sus respectivos tipos. Una vez resvisados, se procede a crear el <i>dataframe</i> de Pandas con los tipos de dato correctos y con el contenido del fichero CSV.</p>

# %%
strokes = pd.read_csv('datasets/healthcare-dataset-stroke-data.csv', dtype={'gender': 'category', 'age': float, 'hypertension': 'int8', 'heart_disease': 'int8', 'ever_married': 'category', 'work_type': 'category', 'Residence_type': 'category','avg_glucose_level': float, 'bmi': float, 'smoking_status': 'category', 'stroke': 'int8'})
strokes
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %% [markdown]
# <p>Una vez importados los datos, se procede a comprobar si se han leído correctamente mediante el siguiente código. Además, Pandas mostrará información sobre el número de filas no nulas de cada atributo. Para que el conjunto de datos sea válido para entrenar un modelo, no deberá tener ningún valor nulo.</p>

# %%
strokes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   category
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int8
#  4   heart_disease      5110 non-null   int8
#  5   ever_married       5110 non-null   category
#  6   work_type          5110 non-null   category
#  7   Residence_type     5110 non-null   category
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   category
#  11  stroke             5110 non-null   int8
# dtypes: category(5), float64(3), int64(1), int8(3)
# memory usage: 200.5 KB

# %% [markdown]
# <p>Como se puede ver, el <i>dataset</i> tiene un total de 5110 entradas y 12 columnas. Todos los atributos tienen valor en la totalidad de las instancias, excepto la columna 9 (bmi), a la que le faltan 201 valores. Existen diferentes técnicas para solucionar este problema, tales como eliminar las filas que contengan los valores nulos, sustituirlos por un número concreto o rellenarlos con la media global de dicha propiedad. Para este caso, se ha considerado esta última solución como la más óptima. Para ello, será tan sencillo como ejecutar el siguiente código:</p>

# %%
strokes = strokes.fillna(strokes.mean())

# %% [markdown]
# <p>Comprobamos que se hayan rellenado correctamente los valores nulos:</p>

# %%
strokes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   category
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int8
#  4   heart_disease      5110 non-null   int8
#  5   ever_married       5110 non-null   category
#  6   work_type          5110 non-null   category
#  7   Residence_type     5110 non-null   category
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   category
#  11  stroke             5110 non-null   int8
# dtypes: category(5), float64(3), int64(1), int8(3)
# memory usage: 200.5 KB

# %% [markdown]
# <p>Además de no contener valores nulos, el <i>dataset</i> deberá ser tratado para convertir los valores de los atributos categóricos en números enteros, de forma que los algoritmos de aprendizaje puedan trabajar con ellos. Para hacer esto, seleccionaremos las columnas de tipo categoría y a cada una le aplicaremos la función <i>cat.codes</i>.</p>

# %%
cat_columns = strokes.select_dtypes(['category']).columns
strokes[cat_columns] = strokes[cat_columns].apply(lambda x: x.cat.codes)

# %% [markdown]
# <p>Como se puede ver, los tipos 'category' han pasado a ser enteros, habiéndose asignado a cada valor de la categoría un número:</p>

# %%
strokes
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046       1  67.0             0              1             1
# 1     51676       0  61.0             0              0             1
# 2     31112       1  80.0             0              1             1
# 3     60182       0  49.0             0              0             1
# 4      1665       0  79.0             1              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5105  18234       0  80.0             1              0             1
# 5106  44873       0  81.0             0              0             1
# 5107  19723       0  35.0             0              0             1
# 5108  37544       1  51.0             0              0             1
# 5109  44679       0  44.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level        bmi  smoking_status  \
# 0             2               1             228.69  36.600000               1
# 1             3               0             202.21  28.893237               2
# 2             2               0             105.92  32.500000               2
# 3             2               1             171.23  34.400000               3
# 4             3               0             174.12  24.000000               2
# ...         ...             ...                ...        ...             ...
# 5105          2               1              83.75  28.893237               2
# 5106          3               1             125.20  40.000000               2
# 5107          3               0              82.99  30.600000               2
# 5108          2               0             166.29  25.600000               1
# 5109          0               1              85.28  26.200000               0
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %% [markdown]
# <p>Una vez preparado el <i>dataset</i>, se puede proceder a construir el <i>dataframe</i> que contenga las características de las que extraer la información y el que almacene la variable objetivo, en este caso el atributo binario 'stroke', el cual determinará si el paciente es propenso a sufrir una isquemia cerebral o no. Para ello, del <i>dataframe</i> completo se han eliminado las columnas 'id' (puesto que no aporta información) y 'stroke' (ya que es la variable objetivo) para construir el de características, y se ha incluido únicamente la columna 'stroke' para crear el <i>dataframe</i> objetivo.</p>

# %%
features = strokes.drop(['stroke', 'id'], axis=1)
target = strokes['stroke']

# %% [markdown]
# <p>El contenido y la estructura de los <i>dataframes</i> son las siguientes:</p>

# %%
features
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 0                  1             228.69  36.600000               1
# 1                  0             202.21  28.893237               2
# 2                  0             105.92  32.500000               2
# 3                  1             171.23  34.400000               3
# 4                  0             174.12  24.000000               2
# ...              ...                ...        ...             ...
# 5105               1              83.75  28.893237               2
# 5106               1             125.20  40.000000               2
# 5107               0              82.99  30.600000               2
# 5108               0             166.29  25.600000               1
# 5109               1              85.28  26.200000               0
#
# [5110 rows x 10 columns]

# %%
target
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int8

# %% [markdown]
# <p>Otro aspecto muy importante a valorar del <i>dataset</i> es su gran desequilibrio entre los casos con accidente cerebrovascular y los pacientes no propensos a él. Como se puede ver, de 5110 casos, solo 249 son positivos. Esto provocará que si utilizamos como método de evaluación del aprendizaje una métrica como la precisión, un predictor trivial que siempre devuelva 0 (no propenso) tendrá una precisión de más del 95% con este <i>dataset</i>. Por tanto, se deberá utilizar otra métrica para evaluar la calidad del modelo de aprendizaje.</p>

# %%
target.value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %% [markdown]
# <p>De todas las métricas posibles para evaluar modelos, se ha escogido la ROC AUC, ya que esta valora que se predigan correctamente tanto los casos positivos como los negativos, pudiendo llegar únicamente al 0,5 de precisión si se predicen sólo los casos negativos, de modo que un predictor trivial tendría un mal rendimiento. De esta manera, se premiará al modelo si es capaz también de 'aprender' y predecir los casos positivos de isquemia, aunque estos sean la minoría.</p>

# %% [markdown]
# <p>Como último paso previo al comienzo del entrenamiento, se deberán dividir los <i>dataframes</i> de características y el objetivo en dos partes cada uno, de manera que se tengan datos para el aprendizaje (en este caso serán el 75% de ellos) y para la prueba de precisión (el 25%)</p>

# %%
training_features, testing_features, training_target, testing_target = \
            train_test_split(features, target, train_size=0.75, test_size=0.25)

# %% [markdown]
# <h2>2. Declaración del clasificador de aprendizaje automático automatizado y búsqueda del mejor modelo</h2>

# %% [markdown]
# <p>La búsqueda del mejor modelo se hará utilizando el método <i>TPOTClassifier</i>, al cual se le pasa por parámetro:
#     <ul>
#         <li>El número de generaciones. Es necesario indicarle al método explícitamente que no hay límite, ya que por defecto se abortará la ejecución transcurridas 100 de ellas</li>
#         <li>El tamaño de la población de cada generación, en este caso 250</li>
#         <li>El método de puntuaje elegido (AUC ROC)</li>
#         <li>La cantidad de información que queremos que nos muestre (valor 2)</li>
#         <li>El tiempo máximo de entrenamiento en minutos (que en este caso será la forma de detener el entrenamiento). Se han establecido 1440 minutos, equivalentes a 24 horas.</li>
#         <li>El parámetro <i>n_jobs</i> configurado para que TPOT haga uso de la totalidad de núcleos del procesador</li>
#     </ul>
#
# Acto seguido se ejecuta el método <i>fit</i>, el cual comenzará a buscar el mejor modelo con la configuración dada. Se parará tras 24 horas.</p>

# %%
tpot = TPOTClassifier(generations=None, population_size=250, scoring='roc_auc', verbosity=2, max_time_mins=1440, n_jobs = -1)
tpot.fit(training_features, training_target)
# Out:
# Optimization Progress:   0%|          | 0/250 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.8434924575301256
#
# Generation 2 - Current best internal CV score: 0.8446732772042262
#
# Generation 3 - Current best internal CV score: 0.8449417605284708
#
# Generation 4 - Current best internal CV score: 0.8452052305258315
#
# Generation 5 - Current best internal CV score: 0.8453307148535167
#
# Generation 6 - Current best internal CV score: 0.8453307148535167
#
# Generation 7 - Current best internal CV score: 0.8455116151439291
#
# Generation 8 - Current best internal CV score: 0.8458420393136297
#
# Generation 9 - Current best internal CV score: 0.8470432630537379
#
# Generation 10 - Current best internal CV score: 0.8470432630537379
#
# Generation 11 - Current best internal CV score: 0.8474389001997192
#
# Generation 12 - Current best internal CV score: 0.8475861073289916
#
# Generation 13 - Current best internal CV score: 0.8489600466721935
#
# Generation 14 - Current best internal CV score: 0.8489600466721935
#
# Generation 15 - Current best internal CV score: 0.8489600466721935
#
# Generation 16 - Current best internal CV score: 0.8489600466721935
#
# Generation 17 - Current best internal CV score: 0.8489600466721935
#
# Generation 18 - Current best internal CV score: 0.8489847015045406
#
# Generation 19 - Current best internal CV score: 0.850056572884316
#
# Generation 20 - Current best internal CV score: 0.850056572884316
#
# Generation 21 - Current best internal CV score: 0.850056572884316
#
# Generation 22 - Current best internal CV score: 0.850056572884316
#
# Generation 23 - Current best internal CV score: 0.850091842520686
#
# Generation 24 - Current best internal CV score: 0.850091842520686
#
# Generation 25 - Current best internal CV score: 0.850091842520686
#
# Generation 26 - Current best internal CV score: 0.850091842520686
#
# Generation 27 - Current best internal CV score: 0.8502078350528249
#
# Generation 28 - Current best internal CV score: 0.8502078350528249
#
# Generation 29 - Current best internal CV score: 0.850391411572239
#
# Generation 30 - Current best internal CV score: 0.850391411572239
#
# Generation 31 - Current best internal CV score: 0.8507115261559235
#
# Generation 32 - Current best internal CV score: 0.8507115261559235
#
# Generation 33 - Current best internal CV score: 0.8509025151126517
#
# Generation 34 - Current best internal CV score: 0.8509025151126517
#
# Generation 35 - Current best internal CV score: 0.8509025151126517
#
# Generation 36 - Current best internal CV score: 0.8509025151126517
#
# Generation 37 - Current best internal CV score: 0.8509025151126517
#
# Generation 38 - Current best internal CV score: 0.8509025151126517
#
# Generation 39 - Current best internal CV score: 0.8509025151126517
#
# Generation 40 - Current best internal CV score: 0.8509025151126517
#
# Generation 41 - Current best internal CV score: 0.850992304436649
#
# Generation 42 - Current best internal CV score: 0.8512772511232992
#
# Generation 43 - Current best internal CV score: 0.8512772511232992
#
# Generation 44 - Current best internal CV score: 0.8512772511232992
#
# Generation 45 - Current best internal CV score: 0.8512772511232992
#
# Generation 46 - Current best internal CV score: 0.8512772511232992
#
# Generation 47 - Current best internal CV score: 0.8512772511232992
#
# Generation 48 - Current best internal CV score: 0.8512772511232992
#
# Generation 49 - Current best internal CV score: 0.8512772511232992
#
# Generation 50 - Current best internal CV score: 0.8512772511232992
#
# Generation 51 - Current best internal CV score: 0.8512772511232992
#
# Generation 52 - Current best internal CV score: 0.8512772511232992
#
# Generation 53 - Current best internal CV score: 0.8512772511232992
#
# Generation 54 - Current best internal CV score: 0.8518626796086852
#
# Generation 55 - Current best internal CV score: 0.8518626796086852
#
# Generation 56 - Current best internal CV score: 0.8518626796086852
#
# Generation 57 - Current best internal CV score: 0.8518626796086852
#
# Generation 58 - Current best internal CV score: 0.8518626796086852
#
# Generation 59 - Current best internal CV score: 0.8518626796086852
#
# Generation 60 - Current best internal CV score: 0.8518626796086852
#
# Generation 61 - Current best internal CV score: 0.8518626796086852
#
# Generation 62 - Current best internal CV score: 0.8518626796086852
#
# Generation 63 - Current best internal CV score: 0.8518626796086852
#
# Generation 64 - Current best internal CV score: 0.853115553987155
#
# Generation 65 - Current best internal CV score: 0.853115553987155
#
# Generation 66 - Current best internal CV score: 0.853115553987155
#
# Generation 67 - Current best internal CV score: 0.853115553987155
#
# Generation 68 - Current best internal CV score: 0.853115553987155
#
# Generation 69 - Current best internal CV score: 0.853115553987155
#
# Generation 70 - Current best internal CV score: 0.853115553987155
#
# Generation 71 - Current best internal CV score: 0.853115553987155
#
# Generation 72 - Current best internal CV score: 0.853115553987155
#
# Generation 73 - Current best internal CV score: 0.853115553987155
#
# Generation 74 - Current best internal CV score: 0.853115553987155
#
# Generation 75 - Current best internal CV score: 0.853115553987155
#
# Generation 76 - Current best internal CV score: 0.853115553987155
#
# Generation 77 - Current best internal CV score: 0.853115553987155
#
# Generation 78 - Current best internal CV score: 0.853115553987155
#
# Generation 79 - Current best internal CV score: 0.853115553987155
#
# Generation 80 - Current best internal CV score: 0.853115553987155
#
# Generation 81 - Current best internal CV score: 0.853115553987155
#
# Generation 82 - Current best internal CV score: 0.853115553987155
#
# Generation 83 - Current best internal CV score: 0.853115553987155
#
# Generation 84 - Current best internal CV score: 0.853115553987155
#
# Generation 85 - Current best internal CV score: 0.853115553987155
#
# Generation 86 - Current best internal CV score: 0.853115553987155
#
# Generation 87 - Current best internal CV score: 0.853115553987155
#
# Generation 88 - Current best internal CV score: 0.853115553987155
#
# Generation 89 - Current best internal CV score: 0.853115553987155
#
# Generation 90 - Current best internal CV score: 0.853115553987155
#
# Generation 91 - Current best internal CV score: 0.853115553987155
#
# Generation 92 - Current best internal CV score: 0.853115553987155
#
# Generation 93 - Current best internal CV score: 0.853115553987155
#
# Generation 94 - Current best internal CV score: 0.853115553987155
#
# Generation 95 - Current best internal CV score: 0.853115553987155
#
# Generation 96 - Current best internal CV score: 0.853115553987155
#
# Generation 97 - Current best internal CV score: 0.853115553987155
#
# Generation 98 - Current best internal CV score: 0.853115553987155
#
# Generation 99 - Current best internal CV score: 0.853115553987155
#
# Generation 100 - Current best internal CV score: 0.853115553987155
#
# Generation 101 - Current best internal CV score: 0.853115553987155
#
# Generation 102 - Current best internal CV score: 0.853115553987155
#
# Generation 103 - Current best internal CV score: 0.853115553987155
#
# Generation 104 - Current best internal CV score: 0.853115553987155
#
# Generation 105 - Current best internal CV score: 0.853115553987155
#
# Generation 106 - Current best internal CV score: 0.853115553987155
#
# Generation 107 - Current best internal CV score: 0.853115553987155
#
# Generation 108 - Current best internal CV score: 0.853115553987155
#
# Generation 109 - Current best internal CV score: 0.8533278752602105
#
# Generation 110 - Current best internal CV score: 0.8533278752602105
#
# Generation 111 - Current best internal CV score: 0.8533278752602105
#
# Generation 112 - Current best internal CV score: 0.8533278752602105
#
# Generation 113 - Current best internal CV score: 0.8533278752602105
#
# Generation 114 - Current best internal CV score: 0.8538512766639419
#
# Generation 115 - Current best internal CV score: 0.8538512766639419
#
# Generation 116 - Current best internal CV score: 0.8538512766639419
#
# Generation 117 - Current best internal CV score: 0.8538512766639419
#
# Generation 118 - Current best internal CV score: 0.8538512766639419
#
# Generation 119 - Current best internal CV score: 0.8538512766639419
#
# Generation 120 - Current best internal CV score: 0.8538512766639419
#
# Generation 121 - Current best internal CV score: 0.8538512766639419
#
# Generation 122 - Current best internal CV score: 0.8538512766639419
# Generation 123 - Current best internal CV score: 0.8538512766639419
#
# Generation 124 - Current best internal CV score: 0.8538512766639419
#
# Generation 125 - Current best internal CV score: 0.8538512766639419
#
# Generation 126 - Current best internal CV score: 0.8538512766639419
#
# Generation 127 - Current best internal CV score: 0.8538512766639419
#
# Generation 128 - Current best internal CV score: 0.8538512766639419
#
# Generation 129 - Current best internal CV score: 0.8538512766639419
#
# Generation 130 - Current best internal CV score: 0.8538512766639419
#
# Generation 131 - Current best internal CV score: 0.8538512766639419
#
# Generation 132 - Current best internal CV score: 0.8538512766639419
#
# Generation 133 - Current best internal CV score: 0.8538512766639419
#
# Generation 134 - Current best internal CV score: 0.8539075317339521
#
# Generation 135 - Current best internal CV score: 0.8539075317339521
#
# Generation 136 - Current best internal CV score: 0.8539075317339521
#
# Generation 137 - Current best internal CV score: 0.8539075317339521
#
# Generation 138 - Current best internal CV score: 0.8539075317339521
#
# Generation 139 - Current best internal CV score: 0.8539075317339521
#
# Generation 140 - Current best internal CV score: 0.8539075317339521
#
# Generation 141 - Current best internal CV score: 0.8539075317339521
#
# Generation 142 - Current best internal CV score: 0.8539651646452514
#
# Generation 143 - Current best internal CV score: 0.8539651646452514
#
# Generation 144 - Current best internal CV score: 0.8539651646452514
#
# Generation 145 - Current best internal CV score: 0.8539651646452514
#
# Generation 146 - Current best internal CV score: 0.8539651646452514
#
# Generation 147 - Current best internal CV score: 0.8539651646452514
#
# Generation 148 - Current best internal CV score: 0.8542534541957885
#
# Generation 149 - Current best internal CV score: 0.8542534541957885
#
# Generation 150 - Current best internal CV score: 0.8542534541957885
#
# Generation 151 - Current best internal CV score: 0.8542534541957885
#
# Generation 152 - Current best internal CV score: 0.8542534541957885
#
# Generation 153 - Current best internal CV score: 0.8542534541957885
#
# Generation 154 - Current best internal CV score: 0.8542534541957885
#
# Generation 155 - Current best internal CV score: 0.8542534541957885
#
# Generation 156 - Current best internal CV score: 0.8542534541957885
#
# Generation 157 - Current best internal CV score: 0.8542534541957885
#
# Generation 158 - Current best internal CV score: 0.8542534541957885
#
# Generation 159 - Current best internal CV score: 0.8542534541957885
#
# Generation 160 - Current best internal CV score: 0.8542534541957885
#
# Generation 161 - Current best internal CV score: 0.8542534541957885
#
# Generation 162 - Current best internal CV score: 0.8542534541957885
#
# Generation 163 - Current best internal CV score: 0.8542534541957885
#
# Generation 164 - Current best internal CV score: 0.8542534541957885
#
# Generation 165 - Current best internal CV score: 0.8542534541957885
#
# Generation 166 - Current best internal CV score: 0.8542534541957885
#
# Generation 167 - Current best internal CV score: 0.8542534541957885
#
# Generation 168 - Current best internal CV score: 0.8542534541957885
#
# Generation 169 - Current best internal CV score: 0.8542534541957885
#
# Generation 170 - Current best internal CV score: 0.8542534541957885
#
# Generation 171 - Current best internal CV score: 0.8542534541957885
#
# Generation 172 - Current best internal CV score: 0.8552316594984039
#
# Generation 173 - Current best internal CV score: 0.8552316594984039
#
# Generation 174 - Current best internal CV score: 0.8552316594984039
#
# Generation 175 - Current best internal CV score: 0.8552316594984039
#
# Generation 176 - Current best internal CV score: 0.8552316594984039
#
# Generation 177 - Current best internal CV score: 0.8552316594984039
#
# Generation 178 - Current best internal CV score: 0.8552316594984039
#
# Generation 179 - Current best internal CV score: 0.8552316594984039
#
# Generation 180 - Current best internal CV score: 0.8552316594984039
#
# Generation 181 - Current best internal CV score: 0.8552316594984039
#
# Generation 182 - Current best internal CV score: 0.8552316594984039
#
# Generation 183 - Current best internal CV score: 0.8552316594984039
#
# Generation 184 - Current best internal CV score: 0.8552316594984039
#
# Generation 185 - Current best internal CV score: 0.8552316594984039
#
# Generation 186 - Current best internal CV score: 0.8552316594984039
#
# Generation 187 - Current best internal CV score: 0.8552316594984039
#
# Generation 188 - Current best internal CV score: 0.8552316594984039
#
# Generation 189 - Current best internal CV score: 0.8552316594984039
#
# Generation 190 - Current best internal CV score: 0.8552316594984039
#
# Generation 191 - Current best internal CV score: 0.8552316594984039
#
# Generation 192 - Current best internal CV score: 0.8552316594984039
#
# Generation 193 - Current best internal CV score: 0.8552316594984039
#
# Generation 194 - Current best internal CV score: 0.8552316594984039
#
# Generation 195 - Current best internal CV score: 0.8552316594984039
#
# Generation 196 - Current best internal CV score: 0.8552316594984039
#
# Generation 197 - Current best internal CV score: 0.8552316594984039
#
# Generation 198 - Current best internal CV score: 0.8552316594984039
#
# Generation 199 - Current best internal CV score: 0.8552316594984039
#
# Generation 200 - Current best internal CV score: 0.8552316594984039
#
# Generation 201 - Current best internal CV score: 0.8552316594984039
#
# Generation 202 - Current best internal CV score: 0.8552316594984039
#
# Generation 203 - Current best internal CV score: 0.8552316594984039
#
# Generation 204 - Current best internal CV score: 0.8552316594984039
#
# Generation 205 - Current best internal CV score: 0.8552316594984039
#
# Generation 206 - Current best internal CV score: 0.8552316594984039
#
# Generation 207 - Current best internal CV score: 0.8552316594984039
#
# Generation 208 - Current best internal CV score: 0.8555173338635406
#
# Generation 209 - Current best internal CV score: 0.855534561724383
#
# Generation 210 - Current best internal CV score: 0.855534561724383
#
# Generation 211 - Current best internal CV score: 0.855534561724383
#
# Generation 212 - Current best internal CV score: 0.855534561724383
#
# Generation 213 - Current best internal CV score: 0.855534561724383
#
# Generation 214 - Current best internal CV score: 0.855534561724383
#
# Generation 215 - Current best internal CV score: 0.855534561724383
#
# Generation 216 - Current best internal CV score: 0.855534561724383
#
# Generation 217 - Current best internal CV score: 0.855534561724383
#
# Generation 218 - Current best internal CV score: 0.855534561724383
#
# Generation 219 - Current best internal CV score: 0.855534561724383
#
# Generation 220 - Current best internal CV score: 0.855534561724383
#
# Generation 221 - Current best internal CV score: 0.855534561724383
#
# Generation 222 - Current best internal CV score: 0.855534561724383
#
# Generation 223 - Current best internal CV score: 0.855534561724383
#
# Generation 224 - Current best internal CV score: 0.855534561724383
#
# Generation 225 - Current best internal CV score: 0.855534561724383
#
# Generation 226 - Current best internal CV score: 0.855534561724383
#
# Generation 227 - Current best internal CV score: 0.855534561724383
#
# Generation 228 - Current best internal CV score: 0.855534561724383
#
# Generation 229 - Current best internal CV score: 0.855534561724383
#
# Generation 230 - Current best internal CV score: 0.855534561724383
#
# Generation 231 - Current best internal CV score: 0.855534561724383
#
# Generation 232 - Current best internal CV score: 0.855534561724383
#
# Generation 233 - Current best internal CV score: 0.855534561724383
#
# Generation 234 - Current best internal CV score: 0.855534561724383
#
# Generation 235 - Current best internal CV score: 0.855534561724383
#
# Generation 236 - Current best internal CV score: 0.855534561724383
#
# Generation 237 - Current best internal CV score: 0.855534561724383
#
# Generation 238 - Current best internal CV score: 0.855534561724383
#
# Generation 239 - Current best internal CV score: 0.855534561724383
#
# Generation 240 - Current best internal CV score: 0.855534561724383
#
# Generation 241 - Current best internal CV score: 0.855534561724383
#
# Generation 242 - Current best internal CV score: 0.855534561724383
# Generation 243 - Current best internal CV score: 0.855534561724383
#
# Generation 244 - Current best internal CV score: 0.855534561724383
#
# Generation 245 - Current best internal CV score: 0.855534561724383
#
# Generation 246 - Current best internal CV score: 0.855534561724383
#
# Generation 247 - Current best internal CV score: 0.855534561724383
#
# Generation 248 - Current best internal CV score: 0.855534561724383
#
# Generation 249 - Current best internal CV score: 0.855534561724383
#
# Generation 250 - Current best internal CV score: 0.855534561724383
#
# Generation 251 - Current best internal CV score: 0.855534561724383
#
# Generation 252 - Current best internal CV score: 0.855534561724383
#
# Generation 253 - Current best internal CV score: 0.855534561724383
#
# Generation 254 - Current best internal CV score: 0.855534561724383
#
# Generation 255 - Current best internal CV score: 0.855534561724383
#
# Generation 256 - Current best internal CV score: 0.8555697829134503
#
# Generation 257 - Current best internal CV score: 0.8555697829134503
#
# Generation 258 - Current best internal CV score: 0.8555697829134503
#
# Generation 259 - Current best internal CV score: 0.8555697829134503
#
# Generation 260 - Current best internal CV score: 0.8555697829134503
#
# Generation 261 - Current best internal CV score: 0.8555697829134503
#
# Generation 262 - Current best internal CV score: 0.8555697829134503
#
# Generation 263 - Current best internal CV score: 0.8555697829134503
#
# Generation 264 - Current best internal CV score: 0.8555697829134503
#
# Generation 265 - Current best internal CV score: 0.8555697829134503
#
# Generation 266 - Current best internal CV score: 0.8555697829134503
#
# Generation 267 - Current best internal CV score: 0.8555697829134503
#
# Generation 268 - Current best internal CV score: 0.8555697829134503
#
# Generation 269 - Current best internal CV score: 0.8555697829134503
#
# Generation 270 - Current best internal CV score: 0.8555697829134503
#
# Generation 271 - Current best internal CV score: 0.8555697829134503
#
# Generation 272 - Current best internal CV score: 0.8555697829134503
#
# Generation 273 - Current best internal CV score: 0.8555697829134503
#
# Generation 274 - Current best internal CV score: 0.8555697829134503
#
# Generation 275 - Current best internal CV score: 0.8555697829134503
#
# Generation 276 - Current best internal CV score: 0.8555697829134503
#
# Generation 277 - Current best internal CV score: 0.8555697829134503
#
# Generation 278 - Current best internal CV score: 0.8555697829134503
#
# Generation 279 - Current best internal CV score: 0.8555697829134503
#
# Generation 280 - Current best internal CV score: 0.8555697829134503
#
# Generation 281 - Current best internal CV score: 0.8555697829134503
#
# Generation 282 - Current best internal CV score: 0.8555697829134503
#
# Generation 283 - Current best internal CV score: 0.8555697829134503
#
# Generation 284 - Current best internal CV score: 0.8555697829134503
#
# Generation 285 - Current best internal CV score: 0.8555697829134503
#
# Generation 286 - Current best internal CV score: 0.8555697829134503
#
# Generation 287 - Current best internal CV score: 0.8555697829134503
#
# Generation 288 - Current best internal CV score: 0.8555697829134503
#
# Generation 289 - Current best internal CV score: 0.8555697829134503
#
# Generation 290 - Current best internal CV score: 0.8555697829134503
#
# Generation 291 - Current best internal CV score: 0.8555697829134503
#
# Generation 292 - Current best internal CV score: 0.8555697829134503
#
# Generation 293 - Current best internal CV score: 0.8555697829134503
#
# Generation 294 - Current best internal CV score: 0.8555697829134503
#
# Generation 295 - Current best internal CV score: 0.8555697829134503
#
# Generation 296 - Current best internal CV score: 0.8555697829134503
#
# Generation 297 - Current best internal CV score: 0.8555697829134503
#
# Generation 298 - Current best internal CV score: 0.8555697829134503
#
# Generation 299 - Current best internal CV score: 0.8555697829134503
#
# Generation 300 - Current best internal CV score: 0.8555697829134503
#
# Generation 301 - Current best internal CV score: 0.8555697829134503
#
# Generation 302 - Current best internal CV score: 0.8555697829134503
#
# Generation 303 - Current best internal CV score: 0.8555697829134503
#
# Generation 304 - Current best internal CV score: 0.8555697829134503
#
# Generation 305 - Current best internal CV score: 0.8555697829134503
#
# Generation 306 - Current best internal CV score: 0.8555697829134503
#
# Generation 307 - Current best internal CV score: 0.8555697829134503
#
# Generation 308 - Current best internal CV score: 0.8555697829134503
#
# Generation 309 - Current best internal CV score: 0.8555697829134503
#
# Generation 310 - Current best internal CV score: 0.8555697829134503
#
# Generation 311 - Current best internal CV score: 0.8555697829134503
#
# Generation 312 - Current best internal CV score: 0.8555697829134503
#
# Generation 313 - Current best internal CV score: 0.8555697829134503
#
# Generation 314 - Current best internal CV score: 0.8555697829134503
#
# Generation 315 - Current best internal CV score: 0.8555697829134503
#
# Generation 316 - Current best internal CV score: 0.8555697829134503
#
# Generation 317 - Current best internal CV score: 0.8555697829134503
#
# Generation 318 - Current best internal CV score: 0.8555697829134503
#
# Generation 319 - Current best internal CV score: 0.8555697829134503
#
# Generation 320 - Current best internal CV score: 0.8555697829134503
#
# Generation 321 - Current best internal CV score: 0.8555697829134503
#
# Generation 322 - Current best internal CV score: 0.8555697829134503
#
# Generation 323 - Current best internal CV score: 0.8555697829134503
#
# Generation 324 - Current best internal CV score: 0.8555697829134503
#
# Generation 325 - Current best internal CV score: 0.8555697829134503
#
# Generation 326 - Current best internal CV score: 0.8555697829134503
#
# Generation 327 - Current best internal CV score: 0.8555697829134503
#
# Generation 328 - Current best internal CV score: 0.8555697829134503
#
# Generation 329 - Current best internal CV score: 0.8555697829134503
#
# Generation 330 - Current best internal CV score: 0.8555697829134503
#
# Generation 331 - Current best internal CV score: 0.8555697829134503
#
# Generation 332 - Current best internal CV score: 0.8555697829134503
#
# Generation 333 - Current best internal CV score: 0.8555697829134503
#
# Generation 334 - Current best internal CV score: 0.8555697829134503
#
# Generation 335 - Current best internal CV score: 0.8555697829134503
#
# Generation 336 - Current best internal CV score: 0.8555697829134503
#
# Generation 337 - Current best internal CV score: 0.8555697829134503
#
# Generation 338 - Current best internal CV score: 0.8555697829134503
#
# Generation 339 - Current best internal CV score: 0.8555697829134503
#
# Generation 340 - Current best internal CV score: 0.8555697829134503
#
# Generation 341 - Current best internal CV score: 0.8555697829134503
#
# Generation 342 - Current best internal CV score: 0.8555697829134503
#
# Generation 343 - Current best internal CV score: 0.8555697829134503
#
# Generation 344 - Current best internal CV score: 0.8555697829134503
#
# Generation 345 - Current best internal CV score: 0.8555697829134503
#
# Generation 346 - Current best internal CV score: 0.8555697829134503
#
# Generation 347 - Current best internal CV score: 0.8555697829134503
#
# Generation 348 - Current best internal CV score: 0.8555697829134503
#
# Generation 349 - Current best internal CV score: 0.8555697829134503
#
# Generation 350 - Current best internal CV score: 0.8555697829134503
#
# Generation 351 - Current best internal CV score: 0.8555697829134503
#
# Generation 352 - Current best internal CV score: 0.8555697829134503
#
# Generation 353 - Current best internal CV score: 0.8555697829134503
#
# Generation 354 - Current best internal CV score: 0.8555697829134503
#
# Generation 355 - Current best internal CV score: 0.8555697829134503
#
# Generation 356 - Current best internal CV score: 0.8555697829134503
#
# Generation 357 - Current best internal CV score: 0.8555697829134503
#
# Generation 358 - Current best internal CV score: 0.8555697829134503
#
# Generation 359 - Current best internal CV score: 0.8555697829134503
#
# Generation 360 - Current best internal CV score: 0.8555697829134503
#
# Generation 361 - Current best internal CV score: 0.8555697829134503
# Generation 362 - Current best internal CV score: 0.8555697829134503
#
# Generation 363 - Current best internal CV score: 0.8555697829134503
#
# Generation 364 - Current best internal CV score: 0.8555697829134503
#
# Generation 365 - Current best internal CV score: 0.8555697829134503
#
# Generation 366 - Current best internal CV score: 0.8555697829134503
#
# Generation 367 - Current best internal CV score: 0.8555697829134503
#
# Generation 368 - Current best internal CV score: 0.8555697829134503
#
# Generation 369 - Current best internal CV score: 0.8555697829134503
#
# Generation 370 - Current best internal CV score: 0.8555697829134503
#
# Generation 371 - Current best internal CV score: 0.8555697829134503
#
# Generation 372 - Current best internal CV score: 0.8555697829134503
#
# Generation 373 - Current best internal CV score: 0.8555697829134503
#
# Generation 374 - Current best internal CV score: 0.8555697829134503
#
# Generation 375 - Current best internal CV score: 0.8555697829134503
#
# Generation 376 - Current best internal CV score: 0.8555697829134503
#
# Generation 377 - Current best internal CV score: 0.8555697829134503
#
# Generation 378 - Current best internal CV score: 0.8555697829134503
#
# Generation 379 - Current best internal CV score: 0.8555697829134503
#
# Generation 380 - Current best internal CV score: 0.8555697829134503
#
# Generation 381 - Current best internal CV score: 0.8555697829134503
#
# Generation 382 - Current best internal CV score: 0.8555697829134503
#
# Generation 383 - Current best internal CV score: 0.8555697829134503
#
# Generation 384 - Current best internal CV score: 0.8555697829134503
#
# Generation 385 - Current best internal CV score: 0.8555697829134503
#
# Generation 386 - Current best internal CV score: 0.8555697829134503
#
# Generation 387 - Current best internal CV score: 0.8557775879289476
#
# Generation 388 - Current best internal CV score: 0.8557775879289476
#
# Generation 389 - Current best internal CV score: 0.8557775879289476
#
# Generation 390 - Current best internal CV score: 0.8557775879289476
#
# Generation 391 - Current best internal CV score: 0.8557775879289476
#
# Generation 392 - Current best internal CV score: 0.8557775879289476
#
# Generation 393 - Current best internal CV score: 0.8557775879289476
#
# Generation 394 - Current best internal CV score: 0.8557775879289476
#
# Generation 395 - Current best internal CV score: 0.8557775879289476
#
# Generation 396 - Current best internal CV score: 0.8557775879289476
#
# Generation 397 - Current best internal CV score: 0.8557775879289476
#
# Generation 398 - Current best internal CV score: 0.8557775879289476
#
# Generation 399 - Current best internal CV score: 0.8557775879289476
#
# Generation 400 - Current best internal CV score: 0.8557775879289476
#
# Generation 401 - Current best internal CV score: 0.8557775879289476
#
# Generation 402 - Current best internal CV score: 0.8557775879289476
#
# Generation 403 - Current best internal CV score: 0.8557775879289476
#
# Generation 404 - Current best internal CV score: 0.8557775879289476
#
# Generation 405 - Current best internal CV score: 0.8557775879289476
#
# Generation 406 - Current best internal CV score: 0.8557775879289476
#
# Generation 407 - Current best internal CV score: 0.8557775879289476
#
# Generation 408 - Current best internal CV score: 0.8557775879289476
#
# Generation 409 - Current best internal CV score: 0.8561798797964284
#
# Generation 410 - Current best internal CV score: 0.8561798797964284
#
# Generation 411 - Current best internal CV score: 0.8561798797964284
#
# Generation 412 - Current best internal CV score: 0.8561798797964284
#
# Generation 413 - Current best internal CV score: 0.8561798797964284
#
# Generation 414 - Current best internal CV score: 0.8561798797964284
#
# Generation 415 - Current best internal CV score: 0.8561798797964284
#
# Generation 416 - Current best internal CV score: 0.8561798797964284
#
# Generation 417 - Current best internal CV score: 0.8561798797964284
#
# Generation 418 - Current best internal CV score: 0.8561798797964284
#
# Generation 419 - Current best internal CV score: 0.8561798797964284
#
# Generation 420 - Current best internal CV score: 0.8561798797964284
#
# Generation 421 - Current best internal CV score: 0.8561798797964284
#
# Generation 422 - Current best internal CV score: 0.8561798797964284
#
# Generation 423 - Current best internal CV score: 0.8561798797964284
#
# Generation 424 - Current best internal CV score: 0.8561798797964284
#
# Generation 425 - Current best internal CV score: 0.8561798797964284
#
# Generation 426 - Current best internal CV score: 0.8561798797964284
#
# Generation 427 - Current best internal CV score: 0.8561798797964284
#
# Generation 428 - Current best internal CV score: 0.8561798797964284
#
# Generation 429 - Current best internal CV score: 0.8561798797964284
#
# Generation 430 - Current best internal CV score: 0.8561798797964284
#
# Generation 431 - Current best internal CV score: 0.8561798797964284
#
# Generation 432 - Current best internal CV score: 0.8561798797964284
#
# Generation 433 - Current best internal CV score: 0.8561798797964284
#
# Generation 434 - Current best internal CV score: 0.8561798797964284
#
# Generation 435 - Current best internal CV score: 0.8561798797964284
#
# Generation 436 - Current best internal CV score: 0.8561798797964284
#
# Generation 437 - Current best internal CV score: 0.8561798797964284
#
# Generation 438 - Current best internal CV score: 0.8561798797964284
#
# Generation 439 - Current best internal CV score: 0.8561798797964284
#
# Generation 440 - Current best internal CV score: 0.8561798797964284
#
# Generation 441 - Current best internal CV score: 0.8561798797964284
#
# Generation 442 - Current best internal CV score: 0.8561798797964284
#
# Generation 443 - Current best internal CV score: 0.8561798797964284
#
# Generation 444 - Current best internal CV score: 0.8561798797964284
#
# Generation 445 - Current best internal CV score: 0.8561798797964284
#
# Generation 446 - Current best internal CV score: 0.8561798797964284
#
# Generation 447 - Current best internal CV score: 0.8561798797964284
#
# Generation 448 - Current best internal CV score: 0.8561798797964284
#
# Generation 449 - Current best internal CV score: 0.8561798797964284
#
# Generation 450 - Current best internal CV score: 0.8561798797964284
#
# Generation 451 - Current best internal CV score: 0.8561798797964284
#
# Generation 452 - Current best internal CV score: 0.8561798797964284
#
# Generation 453 - Current best internal CV score: 0.8561798797964284
#
# Generation 454 - Current best internal CV score: 0.8561798797964284
#
# Generation 455 - Current best internal CV score: 0.8561798797964284
#
# Generation 456 - Current best internal CV score: 0.8561798797964284
#
# Generation 457 - Current best internal CV score: 0.8561798797964284
#
# Generation 458 - Current best internal CV score: 0.8561798797964284
#
# Generation 459 - Current best internal CV score: 0.8561798797964284
#
# Generation 460 - Current best internal CV score: 0.8561798797964284
#
# Generation 461 - Current best internal CV score: 0.8561798797964284
#
# Generation 462 - Current best internal CV score: 0.8561798797964284
#
# Generation 463 - Current best internal CV score: 0.8561798797964284
#
# Generation 464 - Current best internal CV score: 0.8561798797964284
#
# Generation 465 - Current best internal CV score: 0.8561798797964284
#
# Generation 466 - Current best internal CV score: 0.8561798797964284
#
# Generation 467 - Current best internal CV score: 0.8561798797964284
#
# Generation 468 - Current best internal CV score: 0.8561798797964284
#
# Generation 469 - Current best internal CV score: 0.8561798797964284
#
# Generation 470 - Current best internal CV score: 0.8561798797964284
#
# Generation 471 - Current best internal CV score: 0.8561798797964284
#
# Generation 472 - Current best internal CV score: 0.8561798797964284
#
# Generation 473 - Current best internal CV score: 0.8561798797964284
#
# Generation 474 - Current best internal CV score: 0.8561798797964284
#
# Generation 475 - Current best internal CV score: 0.8561798797964284
#
# Generation 476 - Current best internal CV score: 0.8561798797964284
#
# Generation 477 - Current best internal CV score: 0.8561798797964284
#
# Generation 478 - Current best internal CV score: 0.8561798797964284
#
# Generation 479 - Current best internal CV score: 0.8561798797964284
#
# Generation 480 - Current best internal CV score: 0.8561798797964284
# Generation 481 - Current best internal CV score: 0.8561798797964284
#
# Generation 482 - Current best internal CV score: 0.8561798797964284
#
# Generation 483 - Current best internal CV score: 0.8561798797964284
#
# Generation 484 - Current best internal CV score: 0.8561798797964284
#
# Generation 485 - Current best internal CV score: 0.8561798797964284
#
# Generation 486 - Current best internal CV score: 0.8561798797964284
#
# Generation 487 - Current best internal CV score: 0.8561798797964284
#
# 1440.02 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: XGBClassifier(SelectPercentile(SGDClassifier(StandardScaler(CombineDFs(ZeroCount(CombineDFs(input_matrix, XGBClassifier(input_matrix, learning_rate=0.5, max_depth=1, min_child_weight=12, n_estimators=100, n_jobs=1, subsample=0.15000000000000002, verbosity=0))), CombineDFs(CombineDFs(XGBClassifier(input_matrix, learning_rate=0.5, max_depth=5, min_child_weight=12, n_estimators=100, n_jobs=1, subsample=0.15000000000000002, verbosity=0), CombineDFs(input_matrix, input_matrix)), input_matrix))), alpha=0.001, eta0=0.1, fit_intercept=False, l1_ratio=0.0, learning_rate=constant, loss=hinge, penalty=elasticnet, power_t=0.0), percentile=65), learning_rate=0.1, max_depth=9, min_child_weight=19, n_estimators=100, n_jobs=1, subsample=0.35000000000000003, verbosity=0)
# TPOTClassifier(generations=1000000, max_time_mins=1440, n_jobs=-1,
#                population_size=250, scoring='roc_auc', verbosity=2)

# %% [markdown]
# <p>Tras el entrenamiento, evaluamos al mejor modelo o pipeline con los datos de prueba:</p>

# %%
print(tpot.score(testing_features, testing_target))
# Out:
# 0.8314285714285714

# %% [markdown]
# <p>Y se exporta a un archivo a parte</p>

# %%
tpot.export('tpot_stroke_pipeline.py')
